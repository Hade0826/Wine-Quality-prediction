# %% [markdown]
# ### WINE QUALITY PREDICTION

# %%
# Import the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as mno

# %%
# Load data and view it
data = pd.read_csv("winequality-red.csv")

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
data.shape
# Out:
# (1599, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
cols = list(data.columns)

# %%
cols
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
# %matplotlib inline

# %%
for col in cols:
    plt.figure(figsize=(8,5))
    sns.histplot(data=data, x=col)

# %%
for col in cols:
    plt.figure(figsize=(8,5))
    sns.barplot(data=data, y=col, x="quality")

# %%
for col in cols:
    plt.figure(figsize=(8,3))
    sns.boxplot(data=data, x=col)

# %%
for col in cols:
    plt.figure(figsize=(8,5))
    sns.scatterplot(data=data, y=col, x="quality")

# %%
data["quality"].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
data["quality"].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
data.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.124052
# volatile acidity     -0.202288 -0.390558
# citric acid           0.109903  0.226373
# residual sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free sulfur dioxide  -0.069408 -0.050656
# total sulfur dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %%
plt.figure(figsize=(15,9))
sns.heatmap(data.corr(), annot=True, linewidths=1)
# Out:
# <AxesSubplot:>

# %%
mno.bar(data)
# Out:
# <AxesSubplot:>

# %%
# Import Algorithms
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# Import train test split to split data
from sklearn.model_selection import train_test_split, cross_val_score

from sklearn.preprocessing import StandardScaler

# Import evaluation metrics
from sklearn.metrics import accuracy_score, precision_score, f1_score, recall_score, confusion_matrix, classification_report

# %%
#split data into training and testing datasets
x = data.drop("quality", axis=1)
y = data["quality"]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
y.value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
y_dict = dict(y.value_counts())

# %%
y_dict
# Out:
# {5: 681, 6: 638, 7: 199, 4: 53, 8: 18, 3: 10}

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((1279, 11), (1279,), (320, 11), (320,))

# %%
for k, v in y_dict.items():
    per = v/len(y) *100
    print(f"class {k}, n={v}, {per:.2f}%")
# Out:
# class 5, n=681, 42.59%
# class 6, n=638, 39.90%
# class 7, n=199, 12.45%
# class 4, n=53, 3.31%
# class 8, n=18, 1.13%
# class 3, n=10, 0.63%

# %%
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
np.random.seed(0)
#Instantiate models
sv, kn, rf = SVC(), KNeighborsClassifier(), RandomForestClassifier()

#fit my models
sv.fit(x_train, y_train)
kn.fit(x_train, y_train)
rf.fit(x_train, y_train)

#Make predictions with the models
y_pred_sv = sv.predict(x_test)
y_pred_kn = kn.predict(x_test)
y_pred_rf = rf.predict(x_test)

# %%
print(classification_report(y_test, y_pred_sv))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00        11
#            5       0.67      0.75      0.71       135
#            6       0.63      0.68      0.66       142
#            7       0.50      0.30      0.37        27
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.64       320
#    macro avg       0.30      0.29      0.29       320
# weighted avg       0.61      0.64      0.62       320
# C:\Users\CoE_Mobile\Desktop\TY\my_venv\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\CoE_Mobile\Desktop\TY\my_venv\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\CoE_Mobile\Desktop\TY\my_venv\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(classification_report(y_test, y_pred_kn))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00        11
#            5       0.62      0.71      0.66       135
#            6       0.62      0.60      0.61       142
#            7       0.52      0.48      0.50        27
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.61       320
#    macro avg       0.29      0.30      0.30       320
# weighted avg       0.58      0.61      0.59       320
# C:\Users\CoE_Mobile\Desktop\TY\my_venv\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\CoE_Mobile\Desktop\TY\my_venv\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\CoE_Mobile\Desktop\TY\my_venv\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00        11
#            5       0.74      0.83      0.78       135
#            6       0.74      0.72      0.73       142
#            7       0.53      0.59      0.56        27
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.72       320
#    macro avg       0.34      0.36      0.35       320
# weighted avg       0.69      0.72      0.70       320
# C:\Users\CoE_Mobile\Desktop\TY\my_venv\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\CoE_Mobile\Desktop\TY\my_venv\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\CoE_Mobile\Desktop\TY\my_venv\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Balancing the datasets

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

# %%
oversample = SMOTE()
undersample = RandomUnderSampler()
steps = [("o", oversample), ("u", undersample)]
pipeline = Pipeline(steps=steps)
x2, y2 = pipeline.fit_resample(x, y)

# %%
y_dict2 = dict(y2.value_counts())

# %%
y_dict2
# Out:
# {3: 681, 4: 681, 5: 681, 6: 681, 7: 681, 8: 681}

# %%
for k, v in y_dict2.items():
    per = v/len(y2) *100
    print(f"class {k}, n={v}, {per:.2f}%")
# Out:
# class 3, n=681, 16.67%
# class 4, n=681, 16.67%
# class 5, n=681, 16.67%
# class 6, n=681, 16.67%
# class 7, n=681, 16.67%
# class 8, n=681, 16.67%

# %%
#split data into training and testing datasets
x = data.drop("quality", axis=1)
y = data["quality"]
x_train, x_test, y_train, y_test = train_test_split(x2, y2, test_size=0.2, random_state=0)

# %%
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
np.random.seed(0)
#fit my models
sv.fit(x_train, y_train)
kn.fit(x_train, y_train)
rf.fit(x_train, y_train)

#Make predictions with the models
y_pred_sv = sv.predict(x_test)
y_pred_kn = kn.predict(x_test)
y_pred_rf = rf.predict(x_test)

# %%
print(classification_report(y_test, y_pred_sv))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.93      1.00      0.96       158
#            4       0.72      0.87      0.79       128
#            5       0.71      0.56      0.63       135
#            6       0.59      0.43      0.50       132
#            7       0.72      0.68      0.70       127
#            8       0.79      1.00      0.88       138
#
#     accuracy                           0.76       818
#    macro avg       0.75      0.76      0.74       818
# weighted avg       0.75      0.76      0.75       818

# %%
print(classification_report(y_test, y_pred_kn))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.95      1.00      0.98       158
#            4       0.76      0.95      0.84       128
#            5       0.67      0.49      0.57       135
#            6       0.55      0.35      0.43       132
#            7       0.68      0.81      0.74       127
#            8       0.85      0.98      0.91       138
#
#     accuracy                           0.77       818
#    macro avg       0.74      0.76      0.74       818
# weighted avg       0.75      0.77      0.75       818

# %%
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.99      1.00      0.99       158
#            4       0.90      0.97      0.93       128
#            5       0.81      0.77      0.79       135
#            6       0.78      0.64      0.71       132
#            7       0.83      0.91      0.87       127
#            8       0.95      0.99      0.97       138
#
#     accuracy                           0.89       818
#    macro avg       0.88      0.88      0.88       818
# weighted avg       0.88      0.89      0.88       818

# %% [markdown]
# ### Balancing only the training data

# %%
#split data into training and testing datasets
x = data.drop("quality", axis=1)
y = data["quality"]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
oversample = SMOTE()
undersample = RandomUnderSampler()
steps = [("o", oversample), ("u", undersample)]
pipeline = Pipeline(steps=steps)
x_train2, y_train2 = pipeline.fit_resample(x_train, y_train)

# %%
y_dict3 = dict(y_train2.value_counts())

# %%
y_dict3
# Out:
# {3: 546, 4: 546, 5: 546, 6: 546, 7: 546, 8: 546}

# %%
sc = StandardScaler()
x_train2 = sc.fit_transform(x_train2)
x_test = sc.transform(x_test)

# %%
np.random.seed(0)
#fit my models
sv.fit(x_train2, y_train2)
kn.fit(x_train2, y_train2)
rf.fit(x_train2, y_train2)

#Make predictions with the models
y_pred_sv = sv.predict(x_test)
y_pred_kn = kn.predict(x_test)
y_pred_rf = rf.predict(x_test)

# %%
print(classification_report(y_test, y_pred_sv))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.17      0.36      0.23        11
#            5       0.68      0.56      0.62       135
#            6       0.61      0.44      0.51       142
#            7       0.22      0.48      0.30        27
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.49       320
#    macro avg       0.28      0.31      0.28       320
# weighted avg       0.58      0.49      0.52       320

# %%
print(classification_report(y_test, y_pred_kn))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.11      0.27      0.15        11
#            5       0.68      0.57      0.62       135
#            6       0.56      0.38      0.45       142
#            7       0.29      0.67      0.40        27
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.48       320
#    macro avg       0.27      0.32      0.27       320
# weighted avg       0.56      0.47      0.50       320

# %%
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.25      0.27      0.26        11
#            5       0.77      0.81      0.79       135
#            6       0.77      0.61      0.68       142
#            7       0.41      0.70      0.52        27
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.68       320
#    macro avg       0.37      0.40      0.38       320
# weighted avg       0.71      0.68      0.69       320
